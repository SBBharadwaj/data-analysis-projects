# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
import pandas as pd

# %%
obj=LabelEncoder()
obj1=OneHotEncoder(sparse_output=False)

# %%
df=pd.DataFrame({'Gender':['m','m','f','m','f']})

# %%
df['Gender']=obj.fit_transform(df['Gender'])

# %%
df
# Out:
#    Gender
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0

# %%
df1=pd.DataFrame({'product':['mouse','moniter','machine','motor','keyboard','laptop','television','projector']})

# %%
df1['product']=obj.fit_transform(df1['product'])

# %%
df1
# Out:
#    product
# 0        5
# 1        3
# 2        2
# 3        4
# 4        0
# 5        1
# 6        7
# 7        6

# %%
obj1=OneHotEncoder(sparse_output=False)
data=obj1.fit_transform(df)
col=obj1.get_feature_names_out()
df=pd.DataFrame(data,columns=col)
df
# Out:
#    Gender_f  Gender_m
# 0       0.0       1.0
# 1       0.0       1.0
# 2       1.0       0.0
# 3       0.0       1.0
# 4       1.0       0.0
