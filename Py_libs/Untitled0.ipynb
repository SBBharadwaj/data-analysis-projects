# %%
import pandas as pd
import numpy as np

# %%
df  = pd.read_csv('https://raw.githubusercontent.com/Taj1920/Data-Analysis-Datasets/refs/heads/main/Datasets-Practice/hr_data.csv')

# %%
df.head()
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
a=df.groupby(['department','salary'])['average_montly_hours'].mean()
a
# Out:
# department   salary
# IT           high      194.927711
#              low       201.382594
#              medium    204.295327
# RandD        high      199.745098
#              low       198.747253
#              medium    202.954301
# accounting   high      205.905405
#              low       199.899441
#              medium    201.465672
# hr           high      209.066667
#              low       202.456716
#              medium    193.863510
# management   high      200.248889
#              low       200.744444
#              medium    202.653333
# marketing    high      185.575000
#              low       204.487562
#              medium    196.869681
# product_mng  high      194.632353
#              low       201.048780
#              medium    199.637076
# sales        high      201.178439
#              low       200.363030
#              medium    201.520316
# support      high      203.985816
#              low       198.900524
#              medium    202.535032
# ...

# %%
b=df.groupby(['department','salary'])['number_project'].sum()
b
# Out:
# department   salary
# IT           high       16179
#              low       122642
#              medium    109298
# RandD        high       10187
#              low        72344
#              medium     75499
# accounting   high       15237
#              low        71564
#              medium     67491
# hr           high        9408
#              low        67823
#              medium     69597
# management   high       45056
#              low        36134
#              medium     45597
# marketing    high       14846
#              low        82204
#              medium     74023
# product_mng  high       13235
#              low        90673
#              medium     76461
# sales        high       54117
#              low       420562
#              medium    357094
# support      high       28762
#              low       227940
#              medium    190788
# technical    high       40209
#              low       278605
#              medium    231979
# ...

# %%
import matplotlib.pyplot as plt

# %%
a=df.head()

# %%
plt.plot(a['number_project'],a['employee_id'])
plt.xlabel('abc',fontsize=30,color='red')
# Out:
# Text(0.5, 0, 'abc')
